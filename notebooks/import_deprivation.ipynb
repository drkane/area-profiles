# %%
import pandas as pd

# %%
import json
import os

# %%
df = pd.read_csv(
    "https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/845345/File_7_-_All_IoD2019_Scores__Ranks__Deciles_and_Population_Denominators_3.csv",
    index_col="LSOA code (2011)"
)

# %%
with open('../data/boundaries/E06000001_lsoa.geojson') as a:
    b = json.load(a)

# %%
lsoas = [i["properties"]["code"] for i in b["features"]]

# %%
df.loc[df.index.isin(lsoas), :]
# Out:
#                        LSOA name (2011) Local Authority District code (2019)  \
# LSOA code (2011)
# E01011949               Hartlepool 009A                            E06000001
# E01011950               Hartlepool 008A                            E06000001
# E01011951               Hartlepool 007A                            E06000001
# E01011952               Hartlepool 002A                            E06000001
# E01011953               Hartlepool 002B                            E06000001
# E01011954               Hartlepool 001A                            E06000001
# E01011955               Hartlepool 003A                            E06000001
# E01011957               Hartlepool 003C                            E06000001
# E01011959               Hartlepool 014A                            E06000001
# E01011960               Hartlepool 014B                            E06000001
# E01011961               Hartlepool 012A                            E06000001
# ...

# %%
for i in os.listdir('../data/boundaries/'):
    if i.endswith("_lsoa.geojson"):
        print(i)
# Out:
# E06000001_lsoa.geojson
# E06000002_lsoa.geojson
# E06000003_lsoa.geojson
# E06000004_lsoa.geojson
# E06000005_lsoa.geojson
# E06000006_lsoa.geojson
# E06000007_lsoa.geojson
# E06000008_lsoa.geojson
# E06000009_lsoa.geojson
# E06000010_lsoa.geojson
# E06000011_lsoa.geojson
# E06000012_lsoa.geojson
# E06000013_lsoa.geojson
# E06000014_lsoa.geojson
# E06000015_lsoa.geojson
# E06000016_lsoa.geojson
# E06000017_lsoa.geojson
# E06000018_lsoa.geojson
# E06000019_lsoa.geojson
# E06000020_lsoa.geojson
# E06000021_lsoa.geojson
# E06000022_lsoa.geojson
# E06000023_lsoa.geojson
# E06000024_lsoa.geojson
# E06000025_lsoa.geojson
# E06000026_lsoa.geojson
# E06000027_lsoa.geojson
# E06000028_lsoa.geojson
# E06000029_lsoa.geojson
# E06000030_lsoa.geojson
# E06000031_lsoa.geojson
# E06000032_lsoa.geojson
# E06000033_lsoa.geojson
# E06000034_lsoa.geojson
# E06000035_lsoa.geojson
# E06000036_lsoa.geojson
# E06000037_lsoa.geojson
# E06000038_lsoa.geojson
# E06000039_lsoa.geojson
# E06000040_lsoa.geojson
# ...
